# %% [markdown]
# # **EDA**

# %% [markdown]
# Una vez hecha la división por clusters queremos llevar a cabo predicciones para cada uno de ellos. En este caso tenemos el cluster 0, este clustar se reconoce ya que engloba solamente la categoría de Office Supplies, prsenete en 4 markest que son US, APAC, EU y LATAM. Sus sales van desde 0.44 hasta unos 9900 y el profit de -3700 a casi 5000.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

import sys
sys.path.append("../../../")

from src import funciones_eda as fe

pd.set_option("display.max_columns", None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_cluster_0 = pd.read_pickle("../../../datos/dataframes/df_cluster_0.pkl")
df_cluster_0.head(2)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 8    40155  CA-2014-135909  14-10-2014  21-10-2014  Standard Class
# 10   34577  CA-2011-102988  05-04-2011  09-04-2011    Second Class
#
#    Customer ID Customer Name    Segment        City       State  \
# 8     JW-15220     Jane Waco  Corporate  Sacramento  California
# 10    GM-14695  Greg Maxwell  Corporate  Alexandria    Virginia
#
#           Country  Postal Code Market Region       Product ID  \
# 8   United States      95823.0     US   West  OFF-BI-10003527
# 10  United States      22304.0     US  South  OFF-SU-10002881
#
#            Category Sub-Category  \
# 8   Office Supplies      Binders
# 10  Office Supplies     Supplies
#
#                                          Product Name    Sales  Quantity  \
# 8   Fellowes PB500 Electric Punch Plastic Comb Bin...  5083.96         5
# 10  Martin Yale Chadless Opener Electric Letter Op...  4164.05         5
#
# ...

# %%
fe.exploracion_dataframe(df_cluster_0)
# Out:
# El número de datos es 24654 y el de columnas es 25
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                %_nulos
# Postal Code  75.557719
#  .....................
#
# Los tipos de las columnas son:
#                tipo_dato
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# City              object
# State             object
# Country           object
# Postal Code      float64
# Market            object
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# Shipping Cost    float64
# ...

# %%
df_cluster_0.groupby("Sub-Category")["Sales"].mean().sort_values()
# Out:
# Sub-Category
# Labels         29.840883
# Fasteners      36.277754
# Paper          70.379512
# Envelopes      75.449781
# Art            83.114561
# Binders        85.687226
# Supplies      109.529878
# Storage       244.013719
# Appliances    606.440112
# Name: Sales, dtype: float64

# %%
fe.heatmap_correlacion(df_cluster_0)

# %% [markdown]
# El primer paso es definir la varaiable respuesta que queremos predecir, en este caso al estar trabajando para la empresa la métrica que más les interesa es el profit que van a obtener, por lo que esa será nuestra VR.
#
# Después, tendremos que quedarnos únicamente con las columnas que consideraos necesarias a la hora de hacer las predicciones:
# ['Ship Mode', 'Segment', 'Country', 'Market', 'Sub-Category', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority']
#
# Debemos eliminar Sales puesto que lo que quermos predecir el Profit y si supieramos el Sale y las demás variables dependientes sabríamos el Profit por lo que quitamos esta variable. Además, viendo la matriz de correlación hemos decinido mantener Shipping Coast y Discount puesto que son las más correlacionadas con Profit tanto positiva como negativamente.

# %%
df = df_cluster_0[['Ship Mode', 'Segment', 'Country', 'Market', 'Sub-Category', 'Quantity', 'Discount',
       'Profit', 'Shipping Cost', 'Order Priority']]

# %%
fe.exploracion_dataframe(df)
# Out:
# El número de datos es 24654 y el de columnas es 10
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  .....................
#
# Los tipos de las columnas son:
#                tipo_dato
# Ship Mode         object
# Segment           object
# Country           object
# Market            object
# Sub-Category      object
# Quantity           int64
# Discount         float64
# Profit           float64
# Shipping Cost    float64
# Order Priority    object
#  .....................
#                  count       mean         std        min   25%     50%    75%  \
# Quantity       24654.0   3.771761    2.230016     1.0000  2.00  3.0000   5.00
# Discount       24654.0   0.128778    0.195829     0.0000  0.00  0.0000   0.20
# Profit         24654.0  18.948928  116.052973 -3701.8928  0.78  7.2576  22.05
# ...

# %% [markdown]
# Como podemos observar no hay duplicados ni hay nulos, el ship Mode principal es satdar class, el segment es consumer, el mercado está muy equiibrado, al igual que las sub categorias y el principal order priority es Medium. El profit oscila entre -3000 y 5000. Visualicemos estas variables:

# %% [markdown]
# ### 1. Visualizar numéricas y categóricas.

# %%
df_num, df_cat = fe.separar_df(df)
fe.plot_numericas(df_num)

# %% [markdown]
# Podemos vercomo Quantity tiene comportaminet de categórica.

# %%
fe.plot_categoricas(df_cat)

# %% [markdown]
# De nuevo obervamos las conclusiones que hemos sacado del EDA, por lo que no hay ninguna sopresa.

# %% [markdown]
# ### 2. Visualizar la relación de las numéricas y categóricas con la variable respuesta.

# %%
fe.relacion_vr_numericas(df, "Profit")

# %% [markdown]
# A menor discount mayr profit lo cual no nos sorpende, en cuanto a quantity es complicado describir su comportamiento respecto a profit pues dependerá mucho de la subcategoría elegida.

# %% [markdown]
# ### 3. Correlación entre variables numéricas

# %%
fe.heatmap_correlacion(df)

# %% [markdown]
# Esta mapa ya lo habíamos visto anteiormente, sin embargo, ahora lo hacemos de nuevo con nuestras variables finaes. Como se comentó aunque gráficamente es complicado de ver con esta matriz queda claro que Profit y Shipping coast sí que están algo correlacionadas, al igual que Profit y discount aunque negativamente.

# %% [markdown]
# ### 4. Outliers

# %%
fe.detectar_outliers(df)

# %% [markdown]
# Es comlicado ver los outliers pues en profit aparecen demasiados, este punto se estudiará en más profundidad en la parte  tres.

# %% [markdown]
# # **Gestión de nulos**

# %% [markdown]
# Com no hay nulos finalmente guaradamos el df:

# %%
df.to_pickle("../../../datos/cluster_0/df_nonulls.pkl")
