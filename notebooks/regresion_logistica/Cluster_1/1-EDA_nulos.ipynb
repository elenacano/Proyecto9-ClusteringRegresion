# %% [markdown]
# # **EDA**

# %% [markdown]
# Una vez hecha la división por clusters queremos llevar a cabo predicciones para cada uno de ellos. En este caso tenemos el cluster 1, este clustar se reconoce ya que engloba completamnete a dos categorías: Technology y Furniture, demás, esta presente en todos los makets. Sus sales van desde 0.99 hasta unos 22000 y el profit de -6600 a casi 8400.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

import sys
sys.path.append("../../../")

from src import funciones_eda as fe

pd.set_option("display.max_columns", None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_cluster_1 = pd.read_pickle("../../../datos/dataframes/df_cluster_1.pkl")
df_cluster_1.head(2)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298  CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341   IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
#
#    Customer Name    Segment           City            State        Country  \
# 0    Rick Hansen   Consumer  New York City         New York  United States
# 1  Justin Ritter  Corporate     Wollongong  New South Wales      Australia
#
#    Postal Code Market   Region       Product ID    Category Sub-Category  \
# 0      10024.0     US     East  TEC-AC-10003033  Technology  Accessories
# 1          NaN   APAC  Oceania  FUR-CH-10003950   Furniture       Chairs
#
#                                         Product Name     Sales  Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650         7
# 1          Novimex Executive Leather Armchair, Black  3709.395         9
#
#    Discount    Profit  Shipping Cost Order Priority cluster
# 0       0.0  762.1845         933.57       Critical       1
# 1       0.1 -288.7650         923.63       Critical       1

# %%
fe.exploracion_dataframe(df_cluster_1)
# Out:
# El número de datos es 20017 y el de columnas es 25
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#               %_nulos
# Postal Code  80.17685
#  .....................
#
# Los tipos de las columnas son:
#                tipo_dato
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# City              object
# State             object
# Country           object
# Postal Code      float64
# Market            object
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# Shipping Cost    float64
# Order Priority    object
# cluster           object
#  .....................
#                  count          mean           std       min         25%  \
# Row ID         20017.0  24977.317830  14660.778360     2.000  12036.0000
# Postal Code     3968.0  55645.105847  32088.230492  1040.000  23223.0000
# Sales          20017.0    442.395548    637.346442     0.990    103.3461
# Quantity       20017.0      3.503522      2.263559     1.000      2.0000
# Discount       20017.0      0.151498      0.201854     0.000      0.0000
# Profit         20017.0     47.408875    241.838082 -6599.978     -5.4040
# Shipping Cost  20017.0     47.328241     75.949160     0.040      8.3800
#
#                      50%        75%        max
# Row ID         25232.000  37269.000  51287.000
# Postal Code    60150.000  90008.000  99301.000
# Sales            244.560    529.900  22638.480
# Quantity           3.000      5.000     14.000
# Discount           0.002      0.200      0.850
# Profit            21.900     83.733   8399.976
# Shipping Cost     21.920     53.020    933.570
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna ORDER ID tiene las siguientes valore únicos:
#                  count
# Order ID
# CA-2014-100111       9
# US-2013-159359       7
# ES-2014-2769035      7
# US-2013-123085       7
# MX-2013-127705       7
# La columna ORDER DATE tiene las siguientes valore únicos:
#             count
# Order Date
# 03-09-2014     55
# 18-06-2014     54
# 18-11-2014     52
# 04-11-2014     51
# 26-12-2014     50
# La columna SHIP DATE tiene las siguientes valore únicos:
#             count
# Ship Date
# 07-09-2014     54
# 22-11-2014     53
# 02-10-2014     43
# 17-11-2014     43
# 07-12-2014     42
# La columna SHIP MODE tiene las siguientes valore únicos:
#                 count
# Ship Mode
# Standard Class  12086
# Second Class     3998
# First Class      2907
# Same Day         1026
# La columna CUSTOMER ID tiene las siguientes valore únicos:
#              count
# Customer ID
# AB-10015        43
# MY-18295        41
# SW-20755        41
# SV-20365        40
# HM-14860        38
# La columna CUSTOMER NAME tiene las siguientes valore únicos:
#                  count
# Customer Name
# Muhammed Yedwab     49
# Steven Ward         47
# Aaron Bergman       47
# Ralph Arnett        47
# Seth Vernon         44
# La columna SEGMENT tiene las siguientes valore únicos:
#              count
# Segment
# Consumer     10367
# Corporate     6065
# Home Office   3585
# La columna CITY tiene las siguientes valore únicos:
#                count
# City
# New York City    363
# Los Angeles      304
# Philadelphia     225
# Manila           205
# Santo Domingo    193
# La columna STATE tiene las siguientes valore únicos:
#                  count
# State
# California         803
# England            494
# New York           444
# Texas              381
# New South Wales    348
# La columna COUNTRY tiene las siguientes valore únicos:
#                count
# Country
# United States   3968
# Australia       1229
# Mexico          1152
# France           973
# China            815
# La columna MARKET tiene las siguientes valore únicos:
#         count
# Market
# APAC     4825
# LATAM    4432
# US       3968
# EU       3411
# EMEA     1732
# La columna REGION tiene las siguientes valore únicos:
#          count
# Region
# Central   4181
# South     2600
# North     1871
# EMEA      1732
# Africa    1542
# La columna PRODUCT ID tiene las siguientes valore únicos:
#                  count
# Product ID
# FUR-CH-10003354     28
# FUR-CH-10002647     20
# TEC-AC-10003832     18
# FUR-CH-10000105     16
# FUR-FU-10004270     16
# La columna CATEGORY tiene las siguientes valore únicos:
#             count
# Category
# Technology  10141
# Furniture    9876
# La columna SUB-CATEGORY tiene las siguientes valore únicos:
#               count
# Sub-Category
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Bookcases      2411
# La columna PRODUCT NAME tiene las siguientes valore únicos:
#                                                     count
# Product Name
# Apple Smart Phone, Full Size                           51
# Hon Executive Leather Armchair, Adjustable             49
# Nokia Smart Phone, Full Size                           47
# Office Star Executive Leather Armchair, Adjustable     45
# Hewlett Copy Machine, Color                            45
# La columna ORDER PRIORITY tiene las siguientes valore únicos:
#                 count
# Order Priority
# Medium          11559
# High             6035
# Critical         1486
# Low               937
# La columna CLUSTER tiene las siguientes valore únicos:
#          count
# cluster
# 1        20017

# %%
df_cluster_1.groupby("Sub-Category")["Sales"].mean().sort_values()
# Out:
# Sub-Category
# Furnishings    121.633519
# Accessories    243.654315
# Chairs         437.298126
# Phones         508.437337
# Machines       524.266532
# Bookcases      608.283800
# Copiers        679.008670
# Tables         879.258913
# Name: Sales, dtype: float64

# %%
fe.heatmap_correlacion(df_cluster_1)

# %% [markdown]
# El primer paso es definir la variable respuesta que queremos predecir, en este caso al estar trabajando para la empresa la métrica que más les interesa es el profit que van a obtener, por lo que esa será nuestra VR.
#
# Después, tendremos que quedarnos únicamente con las columnas que consideraos necesarias a la hora de hacer las predicciones:
# ['Ship Mode', 'Segment', 'Country', 'Market', 'Sub-Category', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority']
#
# Debemos eliminar Sales puesto que lo que quermos predecir el Profit y si supieramos el Sale y las demás variables dependientes sabríamos el Profit por lo que quitamos esta variable. Además, viendo la matriz de correlación hemos decinido mantener Shipping Coast y Discount puesto que son las más correlacionadas con Profit tanto positiva como negativamente.

# %%
df = df_cluster_1[['Ship Mode', 'Segment', 'Country', 'Market',  'Category', 'Sub-Category', 'Quantity', 'Discount',
       'Profit', 'Shipping Cost', 'Order Priority']]

# %%
fe.exploracion_dataframe(df)
# Out:
# El número de datos es 20017 y el de columnas es 11
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 1
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  .....................
#
# Los tipos de las columnas son:
#                tipo_dato
# Ship Mode         object
# Segment           object
# Country           object
# Market            object
# Category          object
# Sub-Category      object
# Quantity           int64
# Discount         float64
# Profit           float64
# Shipping Cost    float64
# Order Priority    object
#  .....................
#                  count       mean         std       min    25%     50%  \
# Quantity       20017.0   3.503522    2.263559     1.000  2.000   3.000
# Discount       20017.0   0.151498    0.201854     0.000  0.000   0.002
# Profit         20017.0  47.408875  241.838082 -6599.978 -5.404  21.900
# Shipping Cost  20017.0  47.328241   75.949160     0.040  8.380  21.920
#
#                   75%       max
# Quantity        5.000    14.000
# Discount        0.200     0.850
# Profit         83.733  8399.976
# Shipping Cost  53.020   933.570
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna SHIP MODE tiene las siguientes valore únicos:
#                 count
# Ship Mode
# Standard Class  12086
# Second Class     3998
# First Class      2907
# Same Day         1026
# La columna SEGMENT tiene las siguientes valore únicos:
#              count
# Segment
# Consumer     10367
# Corporate     6065
# Home Office   3585
# La columna COUNTRY tiene las siguientes valore únicos:
#                count
# Country
# United States   3968
# Australia       1229
# Mexico          1152
# France           973
# China            815
# La columna MARKET tiene las siguientes valore únicos:
#         count
# Market
# APAC     4825
# LATAM    4432
# US       3968
# EU       3411
# EMEA     1732
# La columna CATEGORY tiene las siguientes valore únicos:
#             count
# Category
# Technology  10141
# Furniture    9876
# La columna SUB-CATEGORY tiene las siguientes valore únicos:
#               count
# Sub-Category
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Bookcases      2411
# La columna ORDER PRIORITY tiene las siguientes valore únicos:
#                 count
# Order Priority
# Medium          11559
# High             6035
# Critical         1486
# Low               937

# %% [markdown]
# ### 1. Visualizar numéricas y categóricas.

# %%
df_num, df_cat = fe.separar_df(df)
fe.plot_numericas(df_num)

# %% [markdown]
# Podemos vercomo Quantity tiene comportaminet de categórica.

# %%
fe.plot_categoricas(df_cat)

# %% [markdown]
# De nuevo obervamos las conclusiones que hemos sacado del EDA, por lo que no hay ninguna sopresa.

# %% [markdown]
# ### 2. Visualizar la relación de las numéricas y categóricas con la variable respuesta.

# %%
fe.relacion_vr_numericas(df, "Profit")

# %% [markdown]
# A menor discount mayor profit lo cual no nos sorpende, en cuanto a quantity es complicado describir su comportamiento respecto a profit pues dependerá mucho de la subcategoría elegida.

# %% [markdown]
# ### 3. Correlación entre variables numéricas

# %%
fe.heatmap_correlacion(df)

# %% [markdown]
# Esta mapa ya lo habíamos visto anteriormente, sin embargo, ahora lo hacemos de nuevo con nuestras variables finales. Como se comentó aunque gráficamente es complicado de ver con esta matriz queda claro que Profit y Shipping cost sí que están algo correlacionadas, al igual que Profit y discount aunque negativamente.

# %% [markdown]
# ### 4. Outliers

# %%
fe.detectar_outliers(df)

# %% [markdown]
# Es comlicado ver los outliers pues en profit aparecen demasiados, este punto se estudiará en más profundidad en la parte  tres.

# %% [markdown]
# # **Gestión de nulos**

# %% [markdown]
# Com no hay nulos finalmente guaradamos el df:

# %%
df.to_pickle("../../../datos/cluster_1/df_nonulls.pkl")
