# %% [markdown]
# # **EDA**

# %% [markdown]
# Una vez hecha la división por clusters queremos llevar a cabo predicciones para cada uno de ellos. En este caso tenemos el cluster 2, este clustar se reconoce ya que pertenece únicamente a la categoría de Office Supplies, como el cluster 0, sin embargo, el cluster 1 solo está presente en los markets de África, EMEA y Canadá. Sus sales van desde 1 hasta unos 4000 y el profit de -1800 a casi 1400.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

import sys
sys.path.append("../../../")

from src import funciones_eda as fe

pd.set_option("display.max_columns", None)

# %%
df_cluster_2 = pd.read_pickle("../../../datos/dataframes/df_cluster_2.pkl")
df_cluster_2.head(2)
# Out:
#     Row ID      Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 19   49463  TZ-2014-8190  05-12-2014  07-12-2014  Second Class     RH-9555
# 86   45616  MO-2013-8630  23-11-2013  23-11-2013      Same Day      AB-255
#
#            Customer Name      Segment        City             State   Country  \
# 19       Ritsa Hightower     Consumer      Uvinza            Kigoma  Tanzania
# 86  Alejandro Ballentine  Home Office  Casablanca  Grand Casablanca   Morocco
#
#     Postal Code  Market  Region        Product ID         Category  \
# 19          NaN  Africa  Africa  OFF-KIT-10004058  Office Supplies
# 86          NaN  Africa  Africa  OFF-HOO-10001881  Office Supplies
#
#    Sub-Category             Product Name    Sales  Quantity  Discount  Profit  \
# 19   Appliances  KitchenAid Stove, White  3409.74         6       0.0  818.28
# 86   Appliances      Hoover Stove, White  2266.44         4       0.0  113.28
#
#     Shipping Cost Order Priority cluster
# 19         763.38           High       2
# 86         556.45         Medium       2

# %%
fe.exploracion_dataframe(df_cluster_2)
# Out:
# El número de datos es 6619 y el de columnas es 25
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#              %_nulos
# Postal Code    100.0
#  .....................
#
# Los tipos de las columnas son:
#                tipo_dato
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# City              object
# State             object
# Country           object
# Postal Code      float64
# Market            object
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# Shipping Cost    float64
# Order Priority    object
# cluster           object
#  .....................
#                 count          mean          std        min         25%  \
# Row ID         6619.0  46273.666415  2899.231989  41292.000  43741.5000
# Postal Code       0.0           NaN          NaN        NaN         NaN
# Sales          6619.0     86.640823   199.631387      1.161     14.3955
# Quantity       6619.0      2.295362     2.121269      1.000      1.0000
# Discount       6619.0      0.169557     0.285426      0.000      0.0000
# Profit         6619.0      7.751469    81.519996  -1869.876     -2.2440
# Shipping Cost  6619.0      9.628121    26.494941      0.020      1.1900
#
#                     50%       75%       max
# Row ID         46266.00  48786.50  51290.00
# Postal Code         NaN       NaN       NaN
# Sales             30.54     78.12   3955.14
# Quantity           1.00      2.00     14.00
# Discount           0.00      0.60      0.70
# Profit             4.62     15.36   1383.90
# Shipping Cost      3.05      7.89    763.38
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna ORDER ID tiene las siguientes valore únicos:
#               count
# Order ID
# TO-2014-9950      9
# CG-2013-3660      9
# GB-2012-6200      9
# MG-2012-4560      9
# SG-2013-6790      9
# La columna ORDER DATE tiene las siguientes valore únicos:
#             count
# Order Date
# 18-11-2014     31
# 15-11-2012     30
# 18-06-2014     28
# 13-11-2013     26
# 23-06-2014     25
# La columna SHIP DATE tiene las siguientes valore únicos:
#             count
# Ship Date
# 16-06-2014     29
# 17-06-2013     21
# 13-05-2014     21
# 23-11-2014     20
# 18-12-2013     19
# La columna SHIP MODE tiene las siguientes valore únicos:
#                 count
# Ship Mode
# Standard Class   3877
# Second Class     1369
# First Class       982
# Same Day          391
# La columna CUSTOMER ID tiene las siguientes valore únicos:
#              count
# Customer ID
# EL-3735         24
# DV-3045         24
# CC-2220         23
# JS-5940         23
# MK-8160         23
# La columna CUSTOMER NAME tiene las siguientes valore únicos:
#                  count
# Customer Name
# Ed Ludwig           24
# Darrin Van Huff     24
# Chris Cortes        23
# Joni Sundaresam     23
# Mike Kennedy        23
# La columna SEGMENT tiene las siguientes valore únicos:
#              count
# Segment
# Consumer      3367
# Corporate     1978
# Home Office   1274
# La columna CITY tiene las siguientes valore únicos:
#           count
# City
# Lagos       213
# Istanbul    207
# Cairo       154
# Kinshasa    120
# Baghdad     111
# La columna STATE tiene las siguientes valore únicos:
#             count
# State
# Istanbul      274
# Lagos         213
# Gauteng       165
# Al Qahirah    154
# Ontario       142
# La columna COUNTRY tiene las siguientes valore únicos:
#          count
# Country
# Turkey     905
# Nigeria    591
# Iran       398
# Egypt      330
# Morocco    311
# La columna MARKET tiene las siguientes valore únicos:
#         count
# Market
# EMEA     3297
# Africa   3045
# Canada    277
# La columna REGION tiene las siguientes valore únicos:
#         count
# Region
# EMEA     3297
# Africa   3045
# Canada    277
# La columna PRODUCT ID tiene las siguientes valore únicos:
#                   count
# Product ID
# OFF-BIN-10002061     23
# OFF-STA-10001791     22
# OFF-STA-10001747     21
# OFF-FEL-10001865     20
# OFF-CAR-10001577     20
# La columna CATEGORY tiene las siguientes valore únicos:
#                  count
# Category
# Office Supplies   6619
# La columna SUB-CATEGORY tiene las siguientes valore únicos:
#               count
# Sub-Category
# Art            1377
# Binders        1369
# Storage        1282
# Fasteners       474
# Supplies        468
# La columna PRODUCT NAME tiene las siguientes valore únicos:
#                                        count
# Product Name
# Stanley Pencil Sharpener, Water Color     31
# Cardinal Index Tab, Clear                 30
# Smead File Cart, Single Width             30
# Ibico Index Tab, Clear                    29
# Sanford Pencil Sharpener, Water Color     28
# La columna ORDER PRIORITY tiene las siguientes valore únicos:
#                 count
# Order Priority
# Medium           3740
# High             2031
# Critical          545
# Low               303
# La columna CLUSTER tiene las siguientes valore únicos:
#          count
# cluster
# 2         6619

# %%
fe.heatmap_correlacion(df_cluster_2)

# %% [markdown]
# El primer paso es definir la variable respuesta que queremos predecir, en este caso al estar trabajando para la empresa la métrica que más les interesa es el profit que van a obtener, por lo que esa será nuestra VR.
#
# Después, tendremos que quedarnos únicamente con las columnas que consideraos necesarias a la hora de hacer las predicciones:
# ['Ship Mode', 'Segment', 'Country', 'Market', 'Sub-Category', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority']
#
# Debemos eliminar Sales puesto que lo que quermos predecir el Profit y si supieramos el Sale y las demás variables dependientes sabríamos el Profit por lo que quitamos esta variable. Además, viendo la matriz de correlación hemos decinido mantener Shipping Coast y Discount puesto que son las más correlacionadas con Profit tanto positiva como negativamente.

# %%
df = df_cluster_2[['Ship Mode', 'Segment', 'Country', 'Market', 'Sub-Category', 'Quantity', 'Discount',
       'Profit', 'Shipping Cost', 'Order Priority']]

# %%
fe.exploracion_dataframe(df)
# Out:
# El número de datos es 6619 y el de columnas es 10
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 1
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  .....................
#
# Los tipos de las columnas son:
#                tipo_dato
# Ship Mode         object
# Segment           object
# Country           object
# Market            object
# Sub-Category      object
# Quantity           int64
# Discount         float64
# Profit           float64
# Shipping Cost    float64
# Order Priority    object
#  .....................
#                 count      mean        std       min    25%   50%    75%  \
# Quantity       6619.0  2.295362   2.121269     1.000  1.000  1.00   2.00
# Discount       6619.0  0.169557   0.285426     0.000  0.000  0.00   0.60
# Profit         6619.0  7.751469  81.519996 -1869.876 -2.244  4.62  15.36
# Shipping Cost  6619.0  9.628121  26.494941     0.020  1.190  3.05   7.89
#
#                    max
# Quantity         14.00
# Discount          0.70
# Profit         1383.90
# Shipping Cost   763.38
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna SHIP MODE tiene las siguientes valore únicos:
#                 count
# Ship Mode
# Standard Class   3877
# Second Class     1369
# First Class       982
# Same Day          391
# La columna SEGMENT tiene las siguientes valore únicos:
#              count
# Segment
# Consumer      3367
# Corporate     1978
# Home Office   1274
# La columna COUNTRY tiene las siguientes valore únicos:
#          count
# Country
# Turkey     905
# Nigeria    591
# Iran       398
# Egypt      330
# Morocco    311
# La columna MARKET tiene las siguientes valore únicos:
#         count
# Market
# EMEA     3297
# Africa   3045
# Canada    277
# La columna SUB-CATEGORY tiene las siguientes valore únicos:
#               count
# Sub-Category
# Art            1377
# Binders        1369
# Storage        1282
# Fasteners       474
# Supplies        468
# La columna ORDER PRIORITY tiene las siguientes valore únicos:
#                 count
# Order Priority
# Medium           3740
# High             2031
# Critical          545
# Low               303

# %% [markdown]
# ### 1. Visualizar numéricas y categóricas.

# %%
df_num, df_cat = fe.separar_df(df)
fe.plot_numericas(df_num)

# %% [markdown]
# Podemos vercomo Quantity tiene comportaminet de categórica.

# %%
fe.plot_categoricas(df_cat)

# %% [markdown]
# De nuevo obervamos las conclusiones que hemos sacado del EDA, por lo que no hay ninguna sopresa.

# %% [markdown]
# ### 2. Visualizar la relación de las numéricas y categóricas con la variable respuesta.

# %%
fe.relacion_vr_numericas(df, "Profit")

# %% [markdown]
# A menor discount mayor profit lo cual no nos sorpende, en cuanto a quantity es complicado describir su comportamiento respecto a profit pues dependerá mucho de la subcategoría elegida.

# %% [markdown]
# ### 3. Correlación entre variables numéricas

# %%
fe.heatmap_correlacion(df)

# %% [markdown]
# Esta mapa ya lo habíamos visto anteriormente, sin embargo, ahora lo hacemos de nuevo con nuestras variables finales. Como se comentó aunque gráficamente es complicado de ver con esta matriz queda claro que Profit y Shipping cost sí que están algo correlacionadas, al igual que Profit y discount aunque negativamente.

# %% [markdown]
# ### 4. Outliers

# %%
fe.detectar_outliers(df)

# %% [markdown]
# Es comlicado ver los outliers pues en profit aparecen demasiados, este punto se estudiará en más profundidad en la parte  tres.

# %% [markdown]
# # **Gestión de nulos**

# %% [markdown]
# Com no hay nulos finalmente guaradamos el df:

# %%
df.to_pickle("../../../datos/cluster_2/df_nonulls.pkl")
